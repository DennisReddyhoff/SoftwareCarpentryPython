# %% [markdown]
# # Lesson 3: Visualising Data

# %%
import matplotlib.pyplot as matplotlib
import numpy
import seaborn

# %%
data = numpy.loadtxt(fname='../data/inflammation-01.csv', delimiter=',')

# %%
image = matplotlib.imshow(data)
matplotlib.show() # days vs patients

# %%
avg_inflammation = numpy.mean(data, axis=0)  # plot days vs avg inflammation
avg_plot = matplotlib.plot(avg_inflammation)

# %%
max_plot = matplotlib.plot(numpy.max(data, axis=0))  # days vs max inflammation

# %%
min_plot = matplotlib.plot(numpy.min(data, axis=0))

# %% [markdown]
# ## Grouping and subplots

# %% [markdown]
# The function matplotlib.pyplot.figure() creates a space into which we will place all of our plots. The parameter figsize tells Python how big to make this space. Each subplot is placed into the figure using its add_subplot method. The add_subplot method takes 3 parameters. The first denotes how many total rows of subplots there are, the second parameter refers to the total number of subplot columns, and the final parameter denotes which subplot your variable is referencing (left-to-right, top-to-bottom). Each subplot is stored in a different variable (axes1, axes2, axes3). Once a subplot is created, the axes can be titled using the set_xlabel() command (or set_ylabel()). Here are our three plots side by side:

# %%
fig = matplotlib.figure(figsize=(10, 3.0))

axes1 = fig.add_subplot(1, 4, 1)
axes2 = fig.add_subplot(1, 4, 2)
axes3 = fig.add_subplot(1, 4, 3)
axes4 = fig.add_subplot(1, 4, 4)

# example of setting custom axes limits
axes1.set_ylabel('average')
axes1.plot(avg_inflammation)
axes1.set_ylim(numpy.min(avg_inflammation), numpy.max(avg_inflammation) * 1.1)

# example of changing interpolation style
axes2.set_ylabel('max')
axes2.plot(numpy.max(data, axis=0), drawstyle='steps-mid')

axes3.set_ylabel('min')
axes3.plot(numpy.min(data, axis=0))

# exercise: add a plot for std
axes4.set_ylabel('std')
axes4.plot(numpy.std(data, axis=0))

fig.tight_layout()
# Out:
# Text(0, 0.5, 'average')
# (0.0, 14.575000000000001)
# Text(0, 0.5, 'max')
# Text(0, 0.5, 'min')
# Text(0, 0.5, 'std')

# %%
# replot vertically

fig = matplotlib.figure(figsize=(3, 10))

axes1 = fig.add_subplot(4, 1, 1)
axes2 = fig.add_subplot(4, 1, 2)
axes3 = fig.add_subplot(4, 1, 3)
axes4 = fig.add_subplot(4, 1, 4)

# example of setting custom axes limits
axes1.set_ylabel('average')
axes1.plot(avg_inflammation)
axes1.set_ylim(numpy.min(avg_inflammation), numpy.max(avg_inflammation) * 1.1)

# example of changing interpolation style
axes2.set_ylabel('max')
axes2.plot(numpy.max(data, axis=0), drawstyle='steps-mid')

axes3.set_ylabel('min')
axes3.plot(numpy.min(data, axis=0))

# exercise: add a plot for std
axes4.set_ylabel('std')
axes4.plot(numpy.std(data, axis=0))

fig.tight_layout()
# Out:
# Text(0, 0.5, 'average')
# (0.0, 14.575000000000001)
# Text(0, 0.5, 'max')
# Text(0, 0.5, 'min')
# Text(0, 0.5, 'std')
